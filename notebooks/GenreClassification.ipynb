# %%
import pandas as pd
import numpy as np
import sys
import json
import os
import re

# %%
from sklearn.feature_extraction import text      
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.svm import NuSVC
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import GaussianNB

# %%
SONGS_PER_GENRE=10000
SONGS_PER_TRAINING=2000
SONGS_PER_TESTING=200

# %%
def cleanse(text):
  result=re.sub('[^a-zA-Z0-9]',' ',text)
  return result

# %%
partists = pd.read_csv("artists-data.csv")
psongs = pd.read_csv("lyrics-data.csv")

# %%
pop_artists = partists[partists['Genres'] == 'Pop']
pop_songs = pd.merge(psongs, pop_artists, how='inner', left_on='ALink', right_on='Link')
pop_songs.head()
# Out:
#            ALink                                  SName  \
# 0  /luisa-sonza/        Café da Manhã ;P (Com Ludmilla)
# 1  /luisa-sonza/  Anaconda *o* ~~~ (Com Mariah Angeliq)
# 2  /luisa-sonza/                       MULHER DO ANO XD
# 3  /luisa-sonza/                              penhasco.
# 4  /luisa-sonza/                   melhor sozinha :-)-:
#
#                                              SLink  \
# 0   /luisa-sonza/cafe-da-manha-p-com-ludmilla.html
# 1  /luisa-sonza/anaconda-o-com-mariah-angeliq.html
# 2               /luisa-sonza/mulher-do-ano-xd.html
# 3                       /luisa-sonza/penhasco.html
# 4                 /luisa-sonza/melhor-sozinha.html
#
#                                                Lyric language       Artist  \
# 0  Hm\nEu tô falando sério\nSei que de manhã tu j...       pt  Luísa Sonza
# 1  Baby\nÉ cada coisa que eu faco que você nem sa...       pt  Luísa Sonza
# 2  Não se emociona que eu já tô sem tempo\nBaby, ...       pt  Luísa Sonza
# 3  Sabia que a queda era grande\nMas tive que pul...       pt  Luísa Sonza
# 4  Eu gosto tanto de você\nMas isso tudo me dá\nF...       pt  Luísa Sonza
#
#   Genres  Songs  Popularity           Link
# 0    Pop   46.0         8.6  /luisa-sonza/
# 1    Pop   46.0         8.6  /luisa-sonza/
# 2    Pop   46.0         8.6  /luisa-sonza/
# 3    Pop   46.0         8.6  /luisa-sonza/
# 4    Pop   46.0         8.6  /luisa-sonza/

# %%
pop_songs = pop_songs[['Genres', 'Artist', 'SName', 'Lyric']].rename(columns = {'Genres' : 'Genre', 'SName' : 'Song'})
pop_songs = pop_songs.dropna()
pop_songs = pop_songs[pop_songs['Lyric'] != 'Instrumental'].head(SONGS_PER_GENRE).applymap(cleanse)
pop_songs.head()
# Out:
#   Genre       Artist                                   Song  \
# 0   Pop  Lu sa Sonza        Caf  da Manh   P  Com Ludmilla
# 1   Pop  Lu sa Sonza  Anaconda  o       Com Mariah Angeliq
# 2   Pop  Lu sa Sonza                       MULHER DO ANO XD
# 3   Pop  Lu sa Sonza                              penhasco
# 4   Pop  Lu sa Sonza                   melhor sozinha
#
#                                                Lyric
# 0  Hm Eu t  falando s rio Sei que de manh  tu j  ...
# 1  Baby   cada coisa que eu faco que voc  nem sab...
# 2  N o se emociona que eu j  t  sem tempo Baby  e...
# 3  Sabia que a queda era grande Mas tive que pula...
# 4  Eu gosto tanto de voc  Mas isso tudo me d  Fri...

# %%
rartists = pd.read_csv("SpotifyFeatures.csv")
rsongs = pd.read_csv("labeled_lyrics_cleaned.csv")
rartists.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %%
rap_artists=rartists[rartists['genre']=='Rap'][['genre','artist_name']].drop_duplicates()
rap_songs = pd.merge(rsongs, rap_artists, how='inner', left_on='artist', right_on='artist_name')
rap_songs = rap_songs[['genre', 'artist', 'song', 'seq']].rename(columns={'genre':'Genre', 'artist':'Artist', 'song':'Song','seq':'Lyric'})
rap_songs = rap_songs.dropna().head(SONGS_PER_GENRE).applymap(cleanse)
rap_songs.head()
# Out:
#   Genre         Artist                            Song  \
# 0   Rap  Juelz Santana                Back to the Crib
# 1   Rap  Juelz Santana                           Intro
# 2   Rap  Juelz Santana  Dipset  Santana s Town   Skit
# 3   Rap  Juelz Santana           My Problem  Jealousy
# 4   Rap  Juelz Santana                      Back Again
#
#                                                Lyric
# 0  Santana  Chris Breezy  P O L O Da Don    Shawt...
# 1  Yo who that    Me it s Ja    Ja  Come in man  ...
# 2  Yeah  let me call this bitch up  hello  Yo  wh...
# 3     I m sorry     I mean it too    let me talk ...
# 4      Juelz  Yeah nigga  I heard my man Luca was...

# %%
msongs = pd.read_csv("metal_lyrics.csv")
msongs["Genre"] = "Metal"
msongs.head()
# Out:
#          Artist      Album                       Song  \
# 0  ...AAAARRGHH  aaaarrghh          _Gecenin_G__lgesi
# 1  ...AAAARRGHH  aaaarrghh                _Son___afak
# 2  ...AAAARRGHH  aaaarrghh  _F__rt__na_Yakla__yyor...
# 3  ...AAAARRGHH  aaaarrghh  _Ebedi_Buzulun_Ortas__nda
# 4  ...AAAARRGHH  aaaarrghh          _Lanetli_Diyarlar
#
#                                                Lyric  SongNum  Year  Genre
# 0  Kara bulutlar sardГ„В± yine dГѓВјnyamГ„В±\nKГ„...        1     0  Metal
# 1  Dolunay parlak gГѓВ¶rГѓВјnmГѓВјyor bu gece\nBe...        2     0  Metal
# 2  Ay Г„В±Г…ВџГ„В±Г„ВџГ„В±nГ„В±n altГ„В±nda\nYaln...        3     0  Metal
# 3  Ay Г„В±Г…ВџГ„В±Г„ВџГ„В±nГ„В±n altГ„В±nda\nYaln...        4     0  Metal
# 4  YГѓВјrГѓВјyorum yalnГ„В±z baГ…ВџГ„В±ma\nNereye...        5     0  Metal

# %%
metal_songs = msongs[['Genre', 'Artist', 'Song', 'Lyric']]
metal_songs.dropna()
metal_songs.head()
# Out:
#    Genre        Artist                       Song  \
# 0  Metal  ...AAAARRGHH          _Gecenin_G__lgesi
# 1  Metal  ...AAAARRGHH                _Son___afak
# 2  Metal  ...AAAARRGHH  _F__rt__na_Yakla__yyor...
# 3  Metal  ...AAAARRGHH  _Ebedi_Buzulun_Ortas__nda
# 4  Metal  ...AAAARRGHH          _Lanetli_Diyarlar
#
#                                                Lyric
# 0  Kara bulutlar sardГ„В± yine dГѓВјnyamГ„В±\nKГ„...
# 1  Dolunay parlak gГѓВ¶rГѓВјnmГѓВјyor bu gece\nBe...
# 2  Ay Г„В±Г…ВџГ„В±Г„ВџГ„В±nГ„В±n altГ„В±nda\nYaln...
# 3  Ay Г„В±Г…ВџГ„В±Г„ВџГ„В±nГ„В±n altГ„В±nda\nYaln...
# 4  YГѓВјrГѓВјyorum yalnГ„В±z baГ…ВџГ„В±ma\nNereye...

# %%
print("Pop -",len(pop_songs), "| Rap -", len(rap_songs), "| Metal -",len(metal_songs))
# Out:
# Pop - 3232 | Rap - 9049 | Metal - 228288

# %%
training_data = pd.concat([pop_songs.head(SONGS_PER_TRAINING), rap_songs.head(SONGS_PER_TRAINING), metal_songs.head(SONGS_PER_TRAINING)])
training_data.dropna()
# Out:
#       Genre       Artist                                   Song  \
# 0       Pop  Lu sa Sonza        Caf  da Manh   P  Com Ludmilla
# 1       Pop  Lu sa Sonza  Anaconda  o       Com Mariah Angeliq
# 2       Pop  Lu sa Sonza                       MULHER DO ANO XD
# 3       Pop  Lu sa Sonza                              penhasco
# 4       Pop  Lu sa Sonza                   melhor sozinha
# ...     ...          ...                                    ...
# 1995  Metal  ABUSIVENESS                         Fire And Blood
# 1996  Metal  ABUSIVENESS                           Krzyk __witu
# 1997  Metal  ABUSIVENESS                       Wiecznie We Mgle
# 1998  Metal  ABUSIVENESS                                Mogi__a
# 1999  Metal  ABUSIVENESS                     __r__d__o Mej Mocy
#
#                                                   Lyric
# 0     Hm Eu t  falando s rio Sei que de manh  tu j  ...
# 1     Baby   cada coisa que eu faco que voc  nem sab...
# 2     N o se emociona que eu j  t  sem tempo Baby  e...
# 3     Sabia que a queda era grande Mas tive que pula...
# 4     Eu gosto tanto de voc  Mas isso tudo me d  Fri...
# ...                                                 ...
# 1995  O, wild song\nYour everlasting power\nTosses l...
# 1996  W sercu nocy lat dziejГѓВіw zagubionych,\nSpra...
# 1997  SzumiГ„В…ce wichry co serce me, prawiecznГ„В… ...
# 1998  OgieГ…В„ spopieli me ciaГ…В‚o,\nWiatr siГ„В™ p...
# 1999  Rozchylam usta spragnione\nOddechu twego - Nat...
#
# [5992 rows x 4 columns]

# %%
cv = CountVectorizer(strip_accents='ascii', lowercase=True, stop_words='english', analyzer='word')
cv.fit(training_data['Lyric'].values.astype('U'))
bow = cv.transform(training_data['Lyric'].values.astype('U')) 
print(bow.shape[0], 'samples x ',bow.shape[1],'words in vocabulary' )
# Out:
# 6000 samples x  46215 words in vocabulary

# %%
models = {'Logistic Regression' : LogisticRegression(max_iter = 500), 'Linear SVC' : LinearSVC(max_iter = 10000),
          'Decision Tree' : DecisionTreeClassifier(), 'Gradient Descent' : SGDClassifier()}

# %%
for model in models.keys():
    print ("Training", model)
    models[model].fit(bow.toarray(), training_data['Genre'])
# Out:
# Training Logistic Regression
# Training Linear SVC
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Training Decision Tree
# Training Gradient Descent

# %%
test_data = pd.concat([pop_songs.iloc[SONGS_PER_TRAINING:SONGS_PER_TRAINING+SONGS_PER_TESTING], rap_songs.iloc[SONGS_PER_TRAINING:SONGS_PER_TRAINING+SONGS_PER_TESTING], metal_songs.iloc[SONGS_PER_TRAINING:SONGS_PER_TRAINING+SONGS_PER_TESTING]])
test_bow = cv.transform(test_data['Lyric'].values.astype('U'))

# %%
accuracy = {}
pg = test_data[['Artist', 'Song','Genre']]
for model in models.keys():
    print("Evaluating", model)
    pred_genre = models[model].predict(test_bow.toarray())
    pg[model] = pred_genre
    accuracy[model] = accuracy_score(test_data['Genre'], pred_genre)
print ("---Accuracy Scores---")
print(accuracy)
# Out:
# Evaluating Logistic Regression
# Evaluating Linear SVC
# Evaluating Decision Tree
# Evaluating Gradient Descent
# ---Accuracy Scores---
# {'Logistic Regression': 0.8083333333333333, 'Linear SVC': 0.7866666666666666, 'Decision Tree': 0.6966666666666667, 'Gradient Descent': 0.8}

# %%
import statistics
def pred(x):
    user_input = x
    user_bow = cv.transform([cleanse(user_input)]) 
    arr = []
    for model in models.keys():
        pred = models[model].predict(user_bow)[0]
        arr.append(pred)
    print(arr)
    print(statistics.mode(arr))

# %%
pred(input())
# Out:
# To be young and in love in New York City (in New York City) To not know who I am but still know that I'm good long as you're here with me To be drunk and in love in New York City (in New York City) Midnight into morning coffee Burning through the hours talking Damn, I like me better when I'm with you I like me better when I'm with you I knew from the first time, I'd stay for a long time 'cause I like me better when I like me better when I'm with you I don't know what it is but I got that feeling (got that feeling) Waking up in this bed next to you swear the room Yeah, it got no ceiling If we lay, let the day just pass us by I might get to too much talking I might have to tell you something
# ['Pop', 'Pop', 'Pop', 'Pop']
# Pop

# %%
import pickle
pickle.dump(models, open("GnereClassificationModel.pkl", "wb"))
pickle.dump(cv, open("GenreClassificationCV.pkl", "wb"))
